# %%
# Cài đặt một số hàm tiền xử lý văn bản cần thiết
# !pip3 install --user underthesea
import regex as re
from underthesea import word_tokenize
 
uniChars = "àáảãạâầấẩẫậăằắẳẵặèéẻẽẹêềếểễệđìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵÀÁẢÃẠÂẦẤẨẪẬĂẰẮẲẴẶÈÉẺẼẸÊỀẾỂỄỆĐÌÍỈĨỊÒÓỎÕỌÔỒỐỔỖỘƠỜỚỞỠỢÙÚỦŨỤƯỪỨỬỮỰỲÝỶỸỴÂĂĐÔƠƯ"
unsignChars = "aaaaaaaaaaaaaaaaaeeeeeeeeeeediiiiiooooooooooooooooouuuuuuuuuuuyyyyyAAAAAAAAAAAAAAAAAEEEEEEEEEEEDIIIOOOOOOOOOOOOOOOOOOOUUUUUUUUUUUYYYYYAADOOU"
 
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic
dicchar = loaddicchar()

# Hàm chuyển Unicode dựng sẵn về Unicde tổ hợp
def convert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

bang_nguyen_am = [['a', 'à', 'á', 'ả', 'ã', 'ạ', 'a'],
                  ['ă', 'ằ', 'ắ', 'ẳ', 'ẵ', 'ặ', 'aw'],
                  ['â', 'ầ', 'ấ', 'ẩ', 'ẫ', 'ậ', 'aa'],
                  ['e', 'è', 'é', 'ẻ', 'ẽ', 'ẹ', 'e'],
                  ['ê', 'ề', 'ế', 'ể', 'ễ', 'ệ', 'ee'],
                  ['i', 'ì', 'í', 'ỉ', 'ĩ', 'ị', 'i'],
                  ['o', 'ò', 'ó', 'ỏ', 'õ', 'ọ', 'o'],
                  ['ô', 'ồ', 'ố', 'ổ', 'ỗ', 'ộ', 'oo'],
                  ['ơ', 'ờ', 'ớ', 'ở', 'ỡ', 'ợ', 'ow'],
                  ['u', 'ù', 'ú', 'ủ', 'ũ', 'ụ', 'u'],
                  ['ư', 'ừ', 'ứ', 'ử', 'ữ', 'ự', 'uw'],
                  ['y', 'ỳ', 'ý', 'ỷ', 'ỹ', 'ỵ', 'y']]
bang_ky_tu_dau = ['', 'f', 's', 'r', 'x', 'j']

nguyen_am_to_ids = {}

for i in range(len(bang_nguyen_am)):
    for j in range(len(bang_nguyen_am[i]) - 1):
        nguyen_am_to_ids[bang_nguyen_am[i][j]] = (i, j)

def chuan_hoa_dau_tu_tieng_viet(word):
    if not is_valid_vietnam_word(word):
        return word

    chars = list(word)
    dau_cau = 0
    nguyen_am_index = []
    qu_or_gi = False
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x == -1:
            continue
        elif x == 9:  # check qu
            if index != 0 and chars[index - 1] == 'q':
                chars[index] = 'u'
                qu_or_gi = True
        elif x == 5:  # check gi
            if index != 0 and chars[index - 1] == 'g':
                chars[index] = 'i'
                qu_or_gi = True
        if y != 0:
            dau_cau = y
            chars[index] = bang_nguyen_am[x][0]
        if not qu_or_gi or index != 1:
            nguyen_am_index.append(index)
    if len(nguyen_am_index) < 2:
        if qu_or_gi:
            if len(chars) == 2:
                x, y = nguyen_am_to_ids.get(chars[1])
                chars[1] = bang_nguyen_am[x][dau_cau]
            else:
                x, y = nguyen_am_to_ids.get(chars[2], (-1, -1))
                if x != -1:
                    chars[2] = bang_nguyen_am[x][dau_cau]
                else:
                    chars[1] = bang_nguyen_am[5][dau_cau] if chars[1] == 'i' else bang_nguyen_am[9][dau_cau]
            return ''.join(chars)
        return word

    for index in nguyen_am_index:
        x, y = nguyen_am_to_ids[chars[index]]
        if x == 4 or x == 8:  # ê, ơ
            chars[index] = bang_nguyen_am[x][dau_cau]
            return ''.join(chars)

    if len(nguyen_am_index) == 2:
        if nguyen_am_index[-1] == len(chars) - 1:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[0]]]
            chars[nguyen_am_index[0]] = bang_nguyen_am[x][dau_cau]
        else:
            x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
            chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    else:
        x, y = nguyen_am_to_ids[chars[nguyen_am_index[1]]]
        chars[nguyen_am_index[1]] = bang_nguyen_am[x][dau_cau]
    return ''.join(chars)


def is_valid_vietnam_word(word):
    chars = list(word)
    nguyen_am_index = -1
    for index, char in enumerate(chars):
        x, y = nguyen_am_to_ids.get(char, (-1, -1))
        if x != -1:
            if nguyen_am_index == -1:
                nguyen_am_index = index
            else:
                if index - nguyen_am_index != 1:
                    return False
                nguyen_am_index = index
    return True


def chuan_hoa_dau_cau_tieng_viet(sentence):
    sentence = sentence.lower()
    words = sentence.split()
    for index, word in enumerate(words):
        cw = re.sub(r'(^\p{P}*)([p{L}.]*\p{L}+)(\p{P}*$)', r'\1/\2/\3', word).split('/')
        if len(cw) == 3:
            cw[1] = chuan_hoa_dau_tu_tieng_viet(cw[1])
        words[index] = ''.join(cw)
    return ' '.join(words)

def remove_html(txt):
    return re.sub(r'<[^>]*>', '', txt)
# Out:
# Requirement already satisfied: underthesea in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (1.3.5)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from underthesea) (1.1.0)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from underthesea) (1.0.2)
# Requirement already satisfied: unidecode in c:\programdata\anaconda3\lib\site-packages (from underthesea) (1.2.0)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\lib\site-packages (from underthesea) (6.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from underthesea) (2.28.1)
# Requirement already satisfied: Click>=6.0 in c:\programdata\anaconda3\lib\site-packages (from underthesea) (8.0.4)
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (from underthesea) (3.7)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from underthesea) (4.64.1)
# Requirement already satisfied: underthesea-core==0.0.5a2 in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (from underthesea) (0.0.5a2)
# Requirement already satisfied: python-crfsuite>=0.9.6 in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (from underthesea) (0.9.8)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from Click>=6.0->underthesea) (0.4.5)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk->underthesea) (2022.7.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->underthesea) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->underthesea) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->underthesea) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->underthesea) (2.0.4)
# Requirement already satisfied: numpy>=1.14.6 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->underthesea) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->underthesea) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->underthesea) (1.9.1)

# %%
def text_preprocess(document):
    # xóa html code
    document = remove_html(document)
    # chuẩn hóa unicode
    document = convert_unicode(document)
    # chuẩn hóa cách gõ dấu tiếng Việt
    document = chuan_hoa_dau_cau_tieng_viet(document)
    # tách từ
    document = word_tokenize(document, format="text")
    # đưa về lower
    document = document.lower()
    # xóa các ký tự không cần thiết
    document = re.sub(r'[^\s\wáàảãạăắằẳẵặâấầẩẫậéèẻẽẹêếềểễệóòỏõọôốồổỗộơớờởỡợíìỉĩịúùủũụưứừửữựýỳỷỹỵđ_]',' ',document)
    # xóa khoảng trắng thừa
    document = re.sub(r'\s+', ' ', document).strip()
    return document

document = """
Nhân mã quả thực từng tồn tại?
Các nhà nghiên cứu khẳng định những sinh vật nửa người nửa thú trong thần thoại Hy Lạp thực sự tồn tại. Họ tìm thấy không ít những bức họa trên đá mô tả chúng và tin rằng các họa sĩ cổ đại đã thực hiện tác phẩm của mình từ chất liệu cuộc sống. 
Paul Takon từ Bảo tàng Australia ở Sydney và nhà cổ sinh vật học Christopher Chippendale từ Đại học Cambridge cho biết những sinh vật lai kiểu này, trong đó có Nhân mã, có thể đã từng sống song hành cùng cha mẹ nguyên thuỷ của chúng. Ở Australia và Nam Phi, nhóm nghiên cứu phát hiện hàng chục các bức vẽ trên đá mô tả động vật mang đầu người hoặc hình người có đầu động vật, có niên đại hơn 32 nghìn năm. 
Hình tượng Nhân mã.
Lần đầu tiên trong lịch sử, họ đã thực hiện một nghiên cứu chi tiết về những bức vẽ kỳ lạ này, sử dụng khoảng 5.000 bức tranh đá của tổ tiên chúng ta: các nhà khoa học đã hệ thống hoá tần xuất xuất hiện và kiểu người lai được mô tả, cũng như định tuổi của chúng. Sau cùng, nhóm đi đến kết luận rằng người mình thú thực sự tồn tại trong quá khứ xa xưa. Theo các nhà nghiên cứu, người nguyên thuỷ không bao giờ vẽ ra những gì họ không nhìn thấy
Thần thoại La Mã và Hy Lạp cổ đại cũng kể cho chúng ta nghe nhiều về những người có cơ thể động vật, và Nhân mã (centaur) là ví dụ thường gặp nhất. Đó là những sinh vật có thân trên của con người, nhưng với chân của ngựa hoặc các động vật khác, như bò đực, lừa, cừu và thậm chí cả dê. Tên gọi centaur là sự hợp nhất của từ Ken (nghĩa là Tôi giết) và Tauros (nghĩa là bò đực), và nó cũng cho thấy vốn hiểu biết thiên văn của người xưa. Khi chòm sao của cung Nhân mã (với các centaur đang ném một cây giáo) xuất hiện trên bầu trời đêm, chúng ta không thể nhìn thấy Kim ngưu, một trong các biểu tượng của mặt trời.
Chuyên gia về thần thoại học đồng thời là nhà khoa học lịch sử Alexander Guryev cho biết người mình thú là kết quả của hành vi thú dâm - sự giao cấu giữa người và động vật, điều khá phổ biến trong các thời kỳ nguyên thuỷ. Họ cũng lưu ý nhiều tộc người đến tận bây giờ vẫn xem mình là hậu duệ của động vật: Chẳng hạn người Tây Tạng tin chắc họ có nguồn gốc từ khỉ, người Hindu coi ngựa là ông tổ và người Thái xem mình là hậu duệ của chó.Một thần thoại Hy Lạp kể rằng nhà chinh phục Alexander Đại đế được thụ thai trong lần giao phối giữa một con rắn cỏ, do thần Zeus (vị thần bảo trợ cho tất cả các thần và con người) hoá thân với Olympia, con gái của hoàng đế Macedonia. 
sex việc cho_phép giao_cấu giữa những người lính và động được xem là ít xấu_xa hơn quan_hệ với gái_điếm các học_giả đáng kính paracelsus cardano và bà_đỡ nổi_tiếng của thế_kỷ 16 fortunio liceti cũng đã một_vài lần ghi lại sự ra_đời của những đứa trẻ lai động_vật do người sinh ra và người do động_vật sinh ra ghi_chép của họ nói đến ngựa voi chó và thậm_chí cả sư_tử cũng theo alexander guryev nhiều năm trước khoa_học_chính_thống không thừa_nhận khả_năng lai chéo giữa người và động_vật nhưng gần đây những nguồn tin khoa_học đáng chú_ý đã công_bố kết_quả thí_nghiệm gene trong đó các nhà_nghiên_cứu thu được những phôi có một_nửa số tế_bào người và nửa của động_vật từ quan_điểm khoa_học sự khác_biệt giữa người và động_vật chỉ là vài phần_trăm điều đó có nghĩa là không loại_trừ khả_năng những đột_biến tự_phát xảy ra trong các tình_huống hiếm_hoi và việc lai_giống tự_nhiên là hoàn_toàn có_thể trong những trường_hợp như vậy nhà giải_phẫu_học danh_tiếng người đan mạch thomas bartolin v ...

# %%
import pandas as pd
df = pd.read_csv('data.csv', header = None);

# %%
df
# Out:
#                                                       0
# 0     __label__thể_thao thẻ_đỏ của beckham được hủy_...
# 1     __label__thể_thao chelsea bị charlton loại khỏ...
# 2     __label__thể_thao chelsea inter lần đầu bại_tr...
# 3     __label__thể_thao một quả bom tấn gấy chấn_độn...
# 4     __label__thể_thao juventus lập kỷ_lục mới ở se...
# ...                                                 ...
# 1995  __label__ẩm_thực làm kem trà xanh mát lạnh cho...
# 1996  __label__ẩm_thực quán cơm nhắng nướng lạ_miệng...
# 1997  __label__ẩm_thực quán ốc vỉa_hè nhưng phải gọi...
# 1998  __label__ẩm_thực khó cưỡng với ốc chiên ngũ_vị...
# 1999  __label__ẩm_thực làm sữa_chua 3 tầng nhanh ngo...
#
# [2000 rows x 1 columns]

# %%
count = {}
for line in open("data.csv", encoding='utf-8'):
    try:
        key = line.split()[0]
        count[key] = count.get(key, 0) + 1
    except IndexError:
        pass

for key in count:
    print(key, count[key])
# Out:
# __label__thể_thao 200
# __label__chính_trị_xã_hội 200
# __label__khoa_học 200
# __label__âm_nhạc 200
# __label__công_nghệ 200
# __label__thời_trang 200
# __label__giáo_dục 200
# __label__pháp_luật 200
# __label__phim_ảnh 200
# __label__ẩm_thực 200

# %%
# Thống kê các word xuất hiện ở tất cả các nhãn
total_label = 18
vocab = {}
label_vocab = {}
for line in open("database.txt", encoding='utf-8'):
    try: 
        words = line.split()
        # lưu ý từ đầu tiên là nhãn
        label = words[0]
        if label not in label_vocab:
            label_vocab[label] = {}
        for word in words[1:]:
            label_vocab[label][word] = label_vocab[label].get(word, 0) + 1
            if word not in vocab:
                vocab[word] = set()
            vocab[word].add(label)
    except IndexError:
        pass

# %%
count = {}
for word in vocab:
    if len(vocab[word]) == total_label:
        count[word] = min([label_vocab[x][word] for x in label_vocab])
        
sorted_count = sorted(count, key=count.get, reverse=True)
for word in sorted_count[:100]:
    print(word, count[word])
# Out:
# là 77
# các 61
# có 60
# của 58
# được 50
# và 48
# với 47
# trong 45
# cho 40
# một 38
# ở 32
# những 31
# cũng 29
# để 28
# không 28
# vào 28
# nhiều 25
# khi 25
# đến 25
# này 24
# từ 23
# đó 21
# như 21
# rất 19
# còn 19
# làm 18
# người 18
# sẽ 17
# nhất 17
# lại 16
# nhưng 16
# hơn 15
# có_thể 14
# hay 13
# chỉ 12
# cả 12
# sau 12
# nên 12
# zing 11
# vn 11
# cùng 11
# đã 11
# ra 11
# về 11
# tại 10
# khác 10
# đây 10
# phải 10
# trên 10
# theo 9
# thì 9
# nước 9
# mà 8
# biết 8
# việt_nam 8
# bên 7
# lớn 7
# mỗi 7
# hai 6
# qua 6
# đầu 6
# ngày 6
# bằng 6
# nếu 6
# vừa 5
# sự 5
# lên 5
# tới 5
# giúp 5
# đặc_biệt 5
# phần 5
# gần 5
# nhau 5
# vẫn 5
# hàng 5
# nơi 5
# điều 4
# tên 4
# chưa 4
# ngoài 4
# mới 4
# hoặc 4
# 5 4
# bởi 4
# anh 4
# mọi 4
# đều 4
# nó 4
# cái 4
# cần 4
# tạo 4
# cách 4
# đi 4
# tuy_nhiên 4
# đang 4
# do 4
# việc 4
# quá 4
# khiến 3
# 3 3

# %%
# loại stopword khỏi dữ liệu   
stopword = set()

def remove_stopwords(line):
    words = []
    for word in line.strip().split():
        if word not in stopword:
            words.append(word)
    return ' '.join(words)

with open('database.prep', 'w', encoding='utf-8') as fp, open('data.csv', encoding='utf-8') as f:
    for line in f:
        line = remove_stopwords(line)
        fp.write(line + '\n')

# %%
# !dir database.prep
# Out:
#  Volume in drive C is Window
#  Volume Serial Number is B0C1-523D
#
#  Directory of C:\Users\XUAN LOI\Data science\project_I
#
# 13/06/2023  19:38         9,375,096 database.prep
#                1 File(s)      9,375,096 bytes
#                0 Dir(s)  153,768,304,640 bytes free

# %%
# Chia tập train/test
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
test_percent = 0.2

text = []
label = []

with open('database.prep', encoding='utf-8') as f: 
    for line in f:
        words = line.strip().split()
        label.append(words[0])
        text.append(' '.join(words[1:]))

X_train, X_test, y_train, y_test = train_test_split(text, label, test_size=test_percent, random_state=42)

with open('train.txt', 'w', encoding='utf-8') as fp:
    for x, y in zip(X_train, y_train):
        fp.write('{} {}\n'.format(y, x))

with open('test.txt', 'w', encoding='utf-8') as fp: 
    for x, y in zip(X_test, y_test):
        fp.write('{} {}\n'.format(y, x))

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
print(list(label_encoder.classes_), '\n')
y_train = label_encoder.transform(y_train)
y_test = label_encoder.transform(y_test)

print(X_train[0], y_train[0], '\n')
print(X_test[0], y_test[0])
# Out:
# ['__label__chính_trị_xã_hội', '__label__công_nghệ', '__label__giáo_dục', '__label__khoa_học', '__label__phim_ảnh', '__label__pháp_luật', '__label__thể_thao', '__label__thời_trang', '__label__âm_nhạc', '__label__ẩm_thực']
#
# youtube việt_nam tràn_ngập video 18 nghi bị lỗi bộ lọc công_nghệ zing vn phản_hồi từ người dùng cho_biết youtube việt_nam đang bị qua_mặt hàng_loạt các video có nội_dung phản_cảm xuất_hiện tràn_lan ảnh_hưởng nghiêm_trọng đến người dùng trưa 20 6 hàng_loạt người dùng cho_biết youtube việt_nam đang gặp sự_cố về bộ lọc và từ khóa tìm_kiếm các video clip có nội_dung nhạy_cảm được phát_tán một_cách tràn_lan không kiểm_soát chỉ cần gõ một_số từ khóa như 18 hàng_loạt nội_dung liên_quan sẽ được gợi_ý trước_đây những video này đều bị bộ lọc của youtube gỡ bỏ khi phát_hiện có nội_dung phản_cảm nguy_hiểm hơn chủ các video này còn seo cả từ khóa tìm_kiếm để qua_mặt youtube cụ_thể nếu một_số từ khóa nhất_định như new 2017 trong mục tìm_kiếm youtube cho kết_quả tìm_kiếm là hàng trăm các video với nội_dung đồi_trụy được tải lên từ nhiều chủ_tài_khoản khác nhau hàng_loạt các video có nội_dung đồi_trụy đang tràn_lan trên youtube mà không được kiểm_duyệt đa_số các video này đều được thu nhỏ xuống còn khoảng 1 4 so với kích_thước gốc sau đó gắn lên trên một hình_ảnh bất_kỳ theo đúng kích_thước chuẩn của youtube cách này thường được các kênh áp_dụng để lách luật bản_quyền đánh_lừa hệ_thống quét hình_ảnh của google phản_ánh với zing vn anh minh_hoàng ở tp hcm giật_mình phát_hiện ra hàng_loạt video có nội_dung người_lớn đang được gợi_ý khi con_trai anh truy_cập vào ứng_dụng youtube trước_đây youtube quản_lý rất chặt_chẽ về các nội_dung này nên tôi chủ_quan không cài youtube_kids anh cho biết trên thực_tế các video này có lượt xem không cao được tải lên từ khoảng một tuần trước chủ_tài_khoản cũng là thành_viên mới lượt subscriber người dùng đăng_ký theo_dõi thấp các video này đều để từ khóa tìm_kiếm bằng tiếng anh độc_giả chủ_yếu đến từ các quốc_gia bên ngoài tuy_nhiên nếu vô_tình tìm_kiếm vào đúng từ khóa seo của các video thì hàng_loạt gợi_ý chứa nội_dung đồi_trụy sẽ hiện ra để lách luật các chủ_tài_khoản còn seo theo từ khóa tìm_kiếm ở việt_nam trẻ_em chiếm một lượng lớn số truy_cập youtube hàng ngày các video có nội_dung đồi_trụy tiếp_tục tràn_lan trên youtube có_thể gây ảnh_hưởng nghiêm_trọng đến nhóm người dùng nhỏ_tuổi đây không phải là lần đầu_tiên youtube gặp vấn_đề về kiểm_định nội_dung cho trẻ_em mới_đây một kênh youtube có lượt xem lớn là spiderman_frozen_marvel_superhero_real_life bị phạt 30 triệu đồng hồi tháng 1 vì làm nội_dung phản_cảm tranh_cãi về nội_dung video từ kênh youtube nổi_tiếng cho trẻ_em ở vn người dùng internet trong nước chỉ_trích video hướng_dẫn làm bồn tắm thạch của kênh youtube_thơ_nguyễn có chứa cảnh nhân_vật rên_rỉ được cho là không phù_hợp với trẻ_em các chuyên_gia tâm_lý cho_rằng các nội_dung trên youtube cần được kiểm_soát nghiêm_ngặt ngoài các vấn_đề về thuần_phong_mỹ_tục một lượng lớn người dùng là trẻ_em sẽ bị tổn_thương vì chưa nhận_thức đầy_đủ về những nội_dung chúng được tiếp_cận nói với zing vn đại_diện truyền_thông của youtube tại việt_nam từng khẳng_định đây là nền_tả
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()), 
                     ('clf', MultinomialNB())
                    ])
text_clf = text_clf.fit(X_train, y_train)

train_time = time.time() - start_time
print('MNB: ', train_time, 'seconds.')

pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "naive_bayes.pkl"), 'wb'))
# Out:
# MNB:  1.9358305931091309 seconds.

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

# Define the pipeline
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()), 
                     ('clf', MultinomialNB())
                    ])

# Train the model on the training data
text_clf.fit(X_train, y_train)

# Evaluate the accuracy on the test data
accuracy = text_clf.score(X_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.91

# %%
import numpy as np

X_train = np.array(X_train)
y_train = np.array(y_train)

print(X_train.shape)
print(y_train.shape)
print(X_train.dtype)
print(y_train.dtype)
# Out:
# (1600,)
# (1600,)
# <U15812
# int32

# %%
print(np.unique(X_test))
# Out:
# ['10 bản song ca tình_yêu ngọt_ngào nhất âm_nhạc zing vn tình_ca dành cho ngày valentine không nên chỉ giới_hạn đơn_thuần ở những màn song ca kinh_điển qua thời_gian mới và cũ đan_xen nhau sẽ tạo nên hương_vị âm_nhạc tuyệt nhất 1 just give me a reason 2013 pink ft nate ruess_just give_me_a_reason là thành_công bất_ngờ của pink trong năm 2013 nhiều nhà phê_bình nhận_định đây là ca_khúc tuyệt nhất trong album thứ 6 the truth about love mặc_dù nó không được chọn là single đầu_tiên bản song ca đầy giằng_xé nội_tâm giữa giọng hát nội_lực của pink với chất giọng nổi_loạn của nate_ruess trưởng nhóm nhạc fun đã càn_quét hàng_loạt các bảng xếp_hạng trên thế_giới thậm_chí ngay trước khi pink chọn just give_me_a_reason là single tiếp_theo bài_hát đã lọt vào nhiều bảng xếp_hạng nhờ vào lượng tải digital lớn ngoài kỳ_vọng ca_khúc mô_tả tâm_trạng cố_gắng níu_kéo một mối quan_hệ đang trên bờ đổ_vỡ nhiều năm sau nhìn lại có_lẽ nó xứng_đáng được nhắc tới trong danh_sách những bản tình_ca kinh_điển chất giọng song ca hòa_quyện hoàn_hảo trên nền nhạc pop ballad những đoạn piano bass và trống dồn cùng với phần lời tâm_trạng đã làm bật lên vẻ đẹp tinh_túy của tình_yêu trải qua nhiều thử_thách của cuộc_sống video just give me a reason ca_khúc just give me reason 2 written in the stars 1999 elton_john ft leann rimes ca_sĩ gạo_cội của nước anh elton_john đã tạo ra một bản tình_ca xuất_sắc với tài_năng nhạc_đồng_quê leann_rimes written in the star do ông sáng_tác cho vở nhạc_kịch aida aida thắng giải grammy dành cho album vở nhạc_kịch xuất_sắc nhất riêng written in the stars vươn lên vị_trí thứ hai trong bảng xếp_hạng billboard_mỹ và số_một ở canada trong phân cảnh sử_dụng ca_khúc này cặp đôi nhân_vật chính chuẩn_bị chia xa và than_thở cho mối tình không thành vì thân_phận chính_trị nỗi_niềm oán_trách trái ngang của đôi trai tài_gái sắc
_tranh với tốc_độ gỡ bỏ như hiện_nay thì ít_nhất phải 450 năm nữa chúng_ta mới gỡ được tất_cả mìn ẩn kín trong những vùng_đất đã được biết tới chưa nói đến những vùng không xác_định được bởi_vậy các nhà_khoa_học thuộc một_số trường đại_học mỹ đang tìm cách huấn_luyện cho những chú ong định_vị được nơi có mìn trong đất thông_qua nhận_diện mùi 3 robot với bánh_xe vuông trong lịch_sử phát_triển con_người đã đi từ những bánh_xe vuông để đến bánh_xe tròn và ngày_nay lẽ_nào robot cũng như vậy từ một ý_tưởng cho rằng một hệ gồm bánh_xe vuông một công_ty đã sản_xuất robot với những bánh_xe vuông nhằm giữ cân_bằng cho robot nhờ trọng_lực _4 bướm chúa bay không lạc_đường bướm chúa monarch được biết đến nhờ vào những chuyến di_cư dài giữa canada và mexico hằng năm mà không hề bị lạc đường trên suốt 3 000 km bí_mật là trong mắt của chúng có một thiết_bị thu_nhận tia_tử_ngoại giúp chúng định_hướng 5 điều_khiển tốc_độ ánh_sáng các nhà_khoa_học tại trường ecole polytechnique fédérale de lausanne thụy_sĩ công_bố rằng ánh_sáng có_thể đi nhanh hơn ánh_sáng họ cho biết nhờ một loại kính đặc_biệt họ có_thể làm cho ánh_sáng đi chậm lại chỉ ở mức 71 000_kms hoặc cũng có_thể đưa ánh_sáng vượt vận_tốc 300 000 kms nhờ vào một môi_trường cực_kỳ đặc_biệt 6 tại_sao sợi mì spaghetti không_thể đứt làm hai các nhà_khoa_học_pháp đã khám_phá ra vì_sao các sợi mì spaghetti chưa nấu chín chỉ có_thể đứt làm 3_ _5 7 hoặc thậm_chí là 10 đoạn nhỏ tuy_nhiên rất ít khi bị đứt thành hai phần nguyên_nhân là do những bước lượn_sóng đặc_thù của ống mì tại các chỗ cong họ cho rằng phát_hiện này không hề tầm_thường vì có_thể ứng_dụng để nâng cao tính ổn_định của các công_trình _7 trữ khí carbonic trong đại_dương một trong những phương_pháp để giảm ô_nhiễm không_khí là hóa lỏng nó và trữ nó trong một môi_trường khác như là đại_dương chẳng_hạn nhưng khó_khăn là phải bơm chất_lỏng này vào biển ở độ sâu 800 3 000 m để đề_phòng khí carbonic có_thể trở_lại bầu khí_quyển đúng là một ý_tưởng thuộc dạng hết_sức điên_rồ khi cho rằng cá không cần thở như con_người _8 tàu_hỏa chạy bằng biogas chiếc xe_lửa đầu_tiên chạy bằng biogas từ phân bò đầu_tiên trên thế_giới được giới_thiệu ở thụy điển nó có_thể chuyên_chở 60 hành_khách trên chỉ 1 toa và có_thể chạy 600 km đường với tốc_độ tối_đa đạt 130 kmh dù_sao đi_nữa cũng hơn xa tàu_hỏa của việt nam về tốc_độ và giá_cả 9 chiếc gối là một vật có hại cho sức_khỏe của chúng_ta không có điều gì phải ngạc_nhiên khi biết rằng chiếc gối thân_yêu là một môi_trường phát_triển cực_kỳ tốt cho nấm theo một công_trình nghiên_cứu suốt 70 năm ròng_rã của một nhóm các nhà_khoa_học đại_học manchester anh những tế_bào nấm trong gối có khả_năng gây dịch_bệnh kể_c
người dùng thưởng_thức ca_nhạc video hát karaoke cnr 2525 tv đa chức_năng all in one tv đầu_tiên trên thế_giới tích_hợp sẵn đầu đọc cd đầu năm 2000 dòng crt bắt_đầu nhường chỗ cho những mẫu plasma lcd mỏng nhẹ thời_trang kích_thước lớn lúc này lg giới_thiệu mn 60 p z1 0 chiếc tv plasma đầu_tiên trên thế_giới đạt kích_cỡ 60 inch trước đó mẫu tv plasma lớn nhất chỉ có kích_thước 30 inch liên_tiếp các năm sau đó lg ghi_danh vào kỷ_lục thế_giới về tv với hàng_loạt model ấn_tượng nổi_bật là tn 60 s z3 0hr tv_lcd sử_dụng đèn_chiếu đầu_tiên trên thế_giới tích_hợp công_nghệ hdr dn 42 x12x tv plasma đầu_tiên đạt độ tương_phản lên đến 50 00 1 các dòng tv tạo nên tên_tuổi của lg còn có 55lp10d tv lcd full hd 55 inch đầu_tiên trên thế_giới và 5 5 4 7lx9500 tv 3d full led đầu_tiên mn 60 p z1 0 tv plasma đầu_tiên trên thế_giới đạt kích_cỡ tới 60 inch khi thế_giới loay_hoay tìm cách tối_ưu lcd plasma lg đã thực_hiện một cuộc cách_mạng toàn_cầu bằng cách nghiên_cứu và ứng_dụng công_nghệ oled vào năm 2012 công_nghệ này không cần sử_dụng đèn nền cho_phép tv đạt được độ mỏng tối_đa oled có khả_năng thể_hiện màu đen tuyệt_đối và độ tương_phản cao mang lại màu_sắc hiển_thị_chân_thật như cuộc_sống vượt_trội cũng với nghiên_cứu trên hãng đã tạo nên mẫu w7 mỏng hơn điện_thoại người dùng có_thể dễ_dàng dán lên tường như một chiếc gương hay cuộn lại như tờ giấy lg w7 tv oled mỏng có_thể dán lên tường mong_muốn tạo ra một cuộc_sống hạnh_phúc tốt_đẹp hơn trên chặng đường gần 60 năm phát_triển những chiếc tv đã cho thấy sức sáng_tạo vô_biên của lg từ đó khẳng_định hướng đi đúng_đắn của hãng công_nghệ hàn_quốc trong việc tạo ra một thiết_bị nghe nhìn tiệm cận mức hoàn_hảo'
#  '5 nhà_hàng việt vào top 101 nơi ngon nhất châu_á ẩm_thực zing vn trang_web uy_tín dailymeal vừa công_bố top 101 nhà_hàng ngon nhất châu_á trong đó có 5 nhà_hàng việt được vinh_danh để lựa_chọn được danh_sách 101 nhà_hàng tốt nhất châu_á năm 2013 trang_web ẩm_thực nổi_tiếng có trụ_sở ở mỹ dailymeal đã mời hơn 50 chuyên_gia từng sống làm_việc lâu_dài và thường_xuyên tại châu_á bao_gồm các nhà phê_bình ẩm_thực nhà_văn cũng như các blogger nhiều kinh_nghiệm về các món_ăn và du_lịch tham_gia ban_đầu danh_sách đề_cử gồm 202 địa_điểm đến từ 25 thành_phố lớn nhỏ khác nhau thuộc 11 quốc_gia thuộc châu á sau đó các chuyên_gia sẽ dựa vào nhiều tiêu_chí như sự tươi mới đa_dạng của menu chất_lượng và hương_vị của các món_ăn thiết_kế của nhà_hàng và nội_thất của từng phòng ăn dịch_vụ chăm_sóc giá tiền để lựa_chọn ra những gương_mặt xuất_sắ
 có_thể xem video từ mọi góc_độ không_chỉ từ chiếc xe bị tai_nạn mà_còn từ những chiếc xe khác trong khu_vực đó chăm_sóc sức_khỏe từ xa khám bệnh từ xa sẽ trở_thành một điều khả_thi nhờ 5g nhờ giảm thiểu độ trễ các bác_sỹ có_thể thực_hiện một_số quy_trình từ xa matt_grob người phụ_trách mảng công_nghệ của qualcomm cho_biết các nhà_mạng có_thể thiết_lập mạng 5g để thực_hiện các quy_trình y_tế cho một người đang ngồi trước màn_hình youtube vì độ trễ rất nhỏ nên các bác_sỹ có_thể sử_dụng robot để mổ cho bạn từ cách đó cả 1 000 dặm mọi người ở vùng xa_xôi hẻo_lánh có_thể được khám bởi các chuyên_gia ở cách họ nửa vòng trái_đất hội_họp bằng video sẽ thật hơn_bao_giờ_hết ceo của samsung tin rằng nhờ 5g cách chúng_ta giao_tiếp sẽ trở_nên thực hơn tưởng_tượng bạn có_thể trò_chuyện với gia_đình thông_qua những video siêu nét độ_phân_giải cực cao tạo cảm_giác như bạn đang ngồi ngay bên cạnh họ hay bạn cũng có_thể luyện_tập cùng các thành_viên khác trong ban nhạc của bạn dù mọi người đang ở trong những ngôi nhà khác nhau thông_qua video điều này nghe có vẻ đơn_giản nhưng các mạng ngày_nay không_thể đem đến khả_năng giao_tiếp với thời_gian thực chính_xác như_vậy luôn có một độ trễ nhất_định và điều đó khiến chúng_ta luôn bị chênh_lệch nhau với 5g điều này có_thể được khắc_phục ngoài_ra với 5g chúng_ta có_thể tìm_kiếm môt thông_tin trên internet sau đó mở trang đó ra chỉ trong 1 đến 2 giây và nếu muốn bạn có_thể tải cả bộ phim the_guardians of_the galaxy chỉ trong vòng 15 giây chứ không phải 6 phút như với tốc_độ của 4g'
#  '5 ưu_điểm của zenfone_max điện_thoại zing vn dòng smartphone tầm trung của hãng asus nhanh_chóng thu_hút người dùng nhờ nhiều điểm cộng về tính_năng và thời_lượng hoạt_động zenfone_max sở_hữu nhiều thế mạnh nổi_bật so với các đối_thủ trong cùng phân_khúc pin 5 000 mah với dung_lượng pin 5 000 mah zenfone_max hiện là một trong những smartphone sở_hữu viên pin mạnh_mẽ nhất trên thị_trường sau một lần sạc máy cho thời_gian chờ lên đến 38 ngày hỗ_trợ gọi thoại 3g 37 6 giờ lướt web bằng wi fi 32 5 giờ và xem video 22 6 giờ liên_tục ngoài_ra zenfone_max có_thể trở_thành cục sạc dự_phòng để tiếp năng_lượng cho thiết_bị khác thông_qua cáp otg tặng kèm kết_nối 4g lte tốc_độ cao việt_nam đã triển_khai 4g công_nghệ kết_nối tốc_độ cao upload download hoặc chuyển dữ_liệu qua_lại nhanh gấp 10 lần so với 3g trong tầm giá dưới 5 triệu đồng zenfone_max vẫn được asus ưu_ái trang_bị 4g lte sẵn_sàng để người dùng trải nghiệm đường truyền này khi các nhà_mạng chính_thức vào_cuộc hoặc khi du_lịch công_tác ở những nước đã có 4g lte zenfone_max giá dưới 5 triệu đồng của asus ảnh duy_tín camera 13 mp tự_động lấy nét laser camera 13 mp hiện khá
# %%
from sklearn import metrics

# true labels
y_true = [1, 1, 0, 1, 0, 0, 1, 0, 0, 1]

# predicted labels
y_pred = [1, 0, 0, 1, 0, 1, 1, 1, 0, 1]

# calculate precision, recall, and F-score
precision = metrics.precision_score(y_true, y_pred)
recall = metrics.recall_score(y_true, y_pred)
f1_score = metrics.f1_score(y_true, y_pred)

print('Precision:', precision)
print('Recall:', recall)
print('F-score:', f1_score)
# Out:
# Precision: 0.6666666666666666
# Recall: 0.8
# F-score: 0.7272727272727272

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score

# Tạo pipeline gộp CountVectorizer, TfidfTransformer và KNN với độ đo cosine
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', KNeighborsClassifier(n_neighbors=5, metric='cosine'))
])

# Huấn luyện mô hình trên tập huấn luyện
text_clf.fit(X_train, y_train)

# Đánh giá mô hình trên tập kiểm tra
y_pred = text_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('KNN cosine:', accuracy)

pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "knn_cosine.pkl"), 'wb'))
# Out:
# KNN cosine: 0.88
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import accuracy_score

# Tạo pipeline gộp CountVectorizer, TfidfTransformer và KNN với độ đo euclide
text_clf = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', KNeighborsClassifier(n_neighbors=4, metric='euclidean'))
])

# Huấn luyện mô hình trên tập huấn luyện
text_clf.fit(X_train, y_train)

# Đánh giá mô hình trên tập kiểm tra
y_pred = text_clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('KNN euclide:', accuracy)

pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "knn_euclide.pkl"), 'wb'))
# Out:
# KNN euclide: 0.885
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
from sklearn.svm import SVC

start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()),
                     ('clf', SVC(gamma='scale'))
                    ])
text_clf = text_clf.fit(X_train, y_train)

train_time = time.time() - start_time
print('SVM: ', train_time, 'seconds.')

# Save model
pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "svm.pkl"), 'wb'))
# Out:
# SVM:  18.782951831817627 seconds.

# %%
import numpy as np
# Naive Bayes
model = pickle.load(open(os.path.join(MODEL_PATH,"naive_bayes.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('Naive Bayes, Accuracy =', np.mean(y_pred == y_test))

# KNN
model = pickle.load(open(os.path.join(MODEL_PATH,"knn_cosine.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('KNN cosine, Accuracy =', np.mean(y_pred == y_test))

# KNN
model = pickle.load(open(os.path.join(MODEL_PATH,"knn_euclide.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('KNN euclide, Accuracy =', np.mean(y_pred == y_test))

# SVM
model = pickle.load(open(os.path.join(MODEL_PATH,"svm.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('SVM, Accuracy =', np.mean(y_pred == y_test))
    
model = fasttext.load_model(os.path.join(MODEL_PATH,"fasttext.ftz"))
print_results(*model.test('test.txt'))
# Out:
# Naive Bayes, Accuracy = 0.91
# KNN cosine, Accuracy = 0.88
# KNN euclide, Accuracy = 0.885
# SVM, Accuracy = 0.93
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20404\1966881654.py in <module>
#      20 print('SVM, Accuracy =', np.mean(y_pred == y_test))
#      21
# ---> 22 model = fasttext.load_model(os.path.join(MODEL_PATH,"fasttext.ftz"))
#      23 print_results(*model.test('test.txt'))
#
# NameError: name 'fasttext' is not defined

# %%
# !pip3 install --user numpy scipy pybind11 cmake
# !pip3 install --user fasttext
# Out:
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.21.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.9.1)
# Requirement already satisfied: pybind11 in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (2.10.3)
# Requirement already satisfied: cmake in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (3.25.2)
# Requirement already satisfied: fasttext in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (0.9.2)
# Requirement already satisfied: pybind11>=2.2 in c:\users\xuan loi\appdata\roaming\python\python39\site-packages (from fasttext) (2.10.3)
# Requirement already satisfied: setuptools>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from fasttext) (63.4.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from fasttext) (1.21.5)

# %%
# Xem kết quả trên từng nhãn
from sklearn.metrics import classification_report

nb_model = pickle.load(open(os.path.join(MODEL_PATH,"naive_bayes.pkl"), 'rb'))
y_pred = nb_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=list(label_encoder.classes_)))
# Out:
#                            precision    recall  f1-score   support
#
# __label__chính_trị_xã_hội       0.83      0.96      0.89        47
#        __label__công_nghệ       0.89      0.97      0.93        34
#         __label__giáo_dục       0.84      0.97      0.90        33
#         __label__khoa_học       1.00      0.67      0.81        46
#         __label__phim_ảnh       1.00      0.81      0.90        48
#        __label__pháp_luật       0.98      1.00      0.99        44
#         __label__thể_thao       0.97      1.00      0.99        36
#       __label__thời_trang       0.90      0.82      0.86        34
#          __label__âm_nhạc       0.78      1.00      0.88        36
#          __label__ẩm_thực       0.95      0.95      0.95        42
#
#                  accuracy                           0.91       400
#                 macro avg       0.92      0.92      0.91       400
#              weighted avg       0.92      0.91      0.91       400

# %%
# xem kết quả cho 1 văn bản model naive bayes đã load ở trên
# Một đoạn bài viết được lấy trên web có nhãn là pháp luật
document = " Tạm giam một trưởng kho tham ô 900 triệu đồng (NLĐ)- Phòng CSĐT tội phạm về trật tự quản lý kinh tế và chức vụ Công an TPHCM vừa ra quyết định khởi tố, bắt tạm giam bị can Lê Diệu (sinh 1949, ngụ quận Tân Bình-TPHCM) nguyên trưởng kho Bách hóa 1 (thuộc Công ty Bách hóa 2 - Bộ Thương Mại) về hành vi tham ô hơn 900 triệu đồng.Theo kết quả điều tra ban đầu của cơ quan công an, với chức trưởng kho, trong 2 năm 2001 đến 2002, ông Diệu đã chỉ đạo cho 2 nhân viên dưới quyền là bà Nguyễn Thị Luyến và Bùi Thị Ngọc Sương thu tiền thuê kho của khách hàng rồi gian lận chứng từ, không nộp đủ tiền về công ty để chia nhau tiêu xài. Tổng số tiền thất thoát lên hơn 900 triệu đồng. Nguyễn Thị Luyến và Bùi Thị Ngọc Sương cũng bị khởi tố về hành vi tham ô nhưng được cho tại ngoại. "

document = text_preprocess(document)
document = remove_stopwords(document)

label = nb_model.predict([document])
print('Predict label:', label_encoder.inverse_transform(label))
# Out:
# Predict label: ['__label__pháp_luật']
